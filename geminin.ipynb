# %%
import requests

# Define the URL
url = 'https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent?key=AIzaSyDevjJ6bMgOjrSR0hJeJ4TAzo4SyVXzyIU'

# Define the headers
headers = {
    'Content-Type': 'application/json'
}

# Define the data payload
data = {
    "contents": [
        {
            "parts": [
                {
                    "text": "make me a questionnire for a new employee"
                }
            ]
        }
    ]
}

# Make the POST request
response = requests.post(url, headers=headers, json=data)

# Print the response
print(response.json())
# Out:
# {'candidates': [{'content': {'parts': [{'text': '## New Employee Questionnaire\n\n**Welcome to [Company Name]!** This questionnaire is designed to help us learn more about you and your experience. Please answer the following questions honestly and to the best of your ability. Your answers will help us better understand your skills, interests, and goals, and will aid in your onboarding process. \n\n**Personal Information:**\n\n1.  **Full Name:**\n2.  **Email Address:**\n3.  **Phone Number:**\n4.  **Date of Birth:**\n5.  **Preferred Pronouns:**\n\n**Employment History:**\n\n6.  **Previous Job Title:**\n7.  **Previous Company:**\n8.  **Dates of Employment:**\n9.  **Briefly describe your responsibilities and accomplishments in your previous role.**\n10. **What are your salary expectations?**\n11. **Do you have any special skills or certifications relevant to this position?**\n12. **What are your strengths and weaknesses?**\n13. **What are your career goals and aspirations?**\n14. **What are your hobbies and interests outside of work?**\n\n**Company & Role:**\n\n15. **How did you hear about this position?**\n16. **What aspects of this job interested you most?**\n17. **What are your expectations for this role?**\n18. **What are your preferred communication methods?**\n19. **Are you comfortable working in a team environment?**\n20. **What are your preferred work hours?**\n21. **Do you have any questions for us?**\n\n**Optional:**\n\n22. **Do you have any special needs or accommodations we should be aware of?**\n23. **Do you have any suggestions for improving our company culture?**\n\n**Please return this completed questionnaire to [Contact Information] by [Date].**\n\n**Thank you for your time and we look forward to working with you!**\n\n**Note:** You can modify this questionnaire based on your specific needs and company culture. Consider adding questions about your company values, employee benefits, and expectations for communication and feedback. \n'}], 'role': 'model'}, 'finishReason': 'STOP', 'index': 0, 'safetyRatings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE'}]}], 'usageMetadata': {'promptTokenCount': 10, 'candidatesTokenCount': 451, 'totalTokenCount': 461}, 'modelVersion': 'gemini-1.5-flash-001'}

# %%
text = response.json()['candidates'][0]['content']['parts'][0]['text']

# %%
text
# Out:
# '## New Employee Questionnaire\n\n**Welcome to [Company Name]!** This questionnaire is designed to help us learn more about you and your experience. Please answer the following questions honestly and to the best of your ability. Your answers will help us better understand your skills, interests, and goals, and will aid in your onboarding process. \n\n**Personal Information:**\n\n1.  **Full Name:**\n2.  **Email Address:**\n3.  **Phone Number:**\n4.  **Date of Birth:**\n5.  **Preferred Pronouns:**\n\n**Employment History:**\n\n6.  **Previous Job Title:**\n7.  **Previous Company:**\n8.  **Dates of Employment:**\n9.  **Briefly describe your responsibilities and accomplishments in your previous role.**\n10. **What are your salary expectations?**\n11. **Do you have any special skills or certifications relevant to this position?**\n12. **What are your strengths and weaknesses?**\n13. **What are your career goals and aspirations?**\n14. **What are your hobbies and interests outside of work?**\n\n**Company & Role:**\n\n15. **How did you hear about this position?**\n16. **What aspects of this job interested you most?**\n17. **What are your expectations for this role?**\n18. **What are your preferred communication methods?**\n19. **Are you comfortable working in a team environment?**\n20. **What are your preferred work hours?**\n21. **Do you have any questions for us?**\n\n**Optional:**\n\n22. **Do you have any special needs or accommodations we should be aware of?**\n23. **Do you have any suggestions for improving our company culture?**\n\n**Please return this completed questionnaire to [Contact Information] by [Date].**\n\n**Thank you for your time and we look forward to working with you!**\n\n**Note:** You can modify this questionnaire based on your specific needs and company culture. Consider adding questions about your company values, employee benefits, and expectations for communication and feedback. \n'

# %%
text_with_new_lines = text.replace('\\n', '\n')
print(text_with_new_lines)
# Out:
# ## New Employee Questionnaire
#
# **Welcome to [Company Name]!** This questionnaire is designed to help us learn more about you and your experience. Please answer the following questions honestly and to the best of your ability. Your answers will help us better understand your skills, interests, and goals, and will aid in your onboarding process.
#
# **Personal Information:**
#
# 1.  **Full Name:**
# 2.  **Email Address:**
# 3.  **Phone Number:**
# 4.  **Date of Birth:**
# 5.  **Preferred Pronouns:**
#
# **Employment History:**
#
# 6.  **Previous Job Title:**
# 7.  **Previous Company:**
# 8.  **Dates of Employment:**
# 9.  **Briefly describe your responsibilities and accomplishments in your previous role.**
# 10. **What are your salary expectations?**
# 11. **Do you have any special skills or certifications relevant to this position?**
# 12. **What are your strengths and weaknesses?**
# 13. **What are your career goals and aspirations?**
# 14. **What are your hobbies and interests outside of work?**
#
# **Company & Role:**
#
# 15. **How did you hear about this position?**
# 16. **What aspects of this job interested you most?**
# 17. **What are your expectations for this role?**
# 18. **What are your preferred communication methods?**
# 19. **Are you comfortable working in a team environment?**
# 20. **What are your preferred work hours?**
# 21. **Do you have any questions for us?**
#
# **Optional:**
#
# 22. **Do you have any special needs or accommodations we should be aware of?**
# 23. **Do you have any suggestions for improving our company culture?**
#
# **Please return this completed questionnaire to [Contact Information] by [Date].**
#
# **Thank you for your time and we look forward to working with you!**
#
# **Note:** You can modify this questionnaire based on your specific needs and company culture. Consider adding questions about your company values, employee benefits, and expectations for communication and feedback.

# %%
import re

# Assuming 'text' is a string variable containing the text with Markdown syntax
text_with_new_lines = text.replace('\\n', '\n')

# Remove common Markdown syntax
cleaned_text = re.sub(r'(\*\*|##|#|_|[*])', '', text_with_new_lines)

print(cleaned_text)
# Out:
#  New Employee Questionnaire
#
# Welcome to [Company Name]! This questionnaire is designed to help us learn more about you and your experience. Please answer the following questions honestly and to the best of your ability. Your answers will help us better understand your skills, interests, and goals, and will aid in your onboarding process.
#
# Personal Information:
#
# 1.  Full Name:
# 2.  Email Address:
# 3.  Phone Number:
# 4.  Date of Birth:
# 5.  Preferred Pronouns:
#
# Employment History:
#
# 6.  Previous Job Title:
# 7.  Previous Company:
# 8.  Dates of Employment:
# 9.  Briefly describe your responsibilities and accomplishments in your previous role.
# 10. What are your salary expectations?
# 11. Do you have any special skills or certifications relevant to this position?
# 12. What are your strengths and weaknesses?
# 13. What are your career goals and aspirations?
# 14. What are your hobbies and interests outside of work?
#
# Company & Role:
#
# 15. How did you hear about this position?
# 16. What aspects of this job interested you most?
# 17. What are your expectations for this role?
# 18. What are your preferred communication methods?
# 19. Are you comfortable working in a team environment?
# 20. What are your preferred work hours?
# 21. Do you have any questions for us?
#
# Optional:
#
# 22. Do you have any special needs or accommodations we should be aware of?
# 23. Do you have any suggestions for improving our company culture?
#
# Please return this completed questionnaire to [Contact Information] by [Date].
#
# Thank you for your time and we look forward to working with you!
#
# Note: You can modify this questionnaire based on your specific needs and company culture. Consider adding questions about your company values, employee benefits, and expectations for communication and feedback.

# %%
import pandas as pd

# %%
df = pd.read_csv('extracted_data_2.csv')

# %%
df.sample(5)
# Out:
#                                                    URL  \
# 249  https://www.orthobullets.com/basic-science/403...
# 163  https://www.orthobullets.com/spine/2068/pediat...
# 446  https://www.orthobullets.com/anatomy/10071/bic...
# 123  https://www.orthobullets.com/anatomy/10055/sar...
# 130  https://www.orthobullets.com/trauma/422820/mor...
#
#                                               Etiology  \
# 249  Pathophysiology\nunknown\ntherories\nactivated...
# 163  Pathophysiology\nmechanism of injury includes:...
# 446                                                NaN
# 123                                                NaN
# 130  Pathophysiology\ndivided into 4 stages:\nshear...
#
#                                               Symptoms
# 249  pruritis, bruning sensation and occasionally p...
# 163                                                NaN
# 446                                                NaN
# 123                                                NaN
# 130  often minimally symptomatic or marginalized du...

# %%
df = df.dropna()

# %%
df.iloc[0]
# Out:
# URL         https://www.orthobullets.com/shoulder-and-elbo...
# Etiology    Pathophysiology\npathoanatomy\ntypically a hig...
# Symptoms    shoulder pain\ninability to move shoulder - ar...
# Name: 0, dtype: object

# %%
text = df.iloc[0]['URL']

# %%
' '.join(text.split('/')[-1].split('-'))
# Out:
# 'luxatio erecta inferior glenohumeral joint dislocation'

# %%
df['Name'] = df['URL'].apply(lambda x: ' '.join(x.split('/')[-1].split('-')))

# %%
df
# Out:
#                                                    URL  \
# 0    https://www.orthobullets.com/shoulder-and-elbo...
# 6    https://www.orthobullets.com/hand/6041/scaphol...
# 8    https://www.orthobullets.com/pediatrics/4080/o...
# 10   https://www.orthobullets.com/knee-and-sports/3...
# 11   https://www.orthobullets.com/foot-and-ankle/70...
# ..                                                 ...
# 443  https://www.orthobullets.com/pediatrics/4116/c...
# 444  https://www.orthobullets.com/pediatrics/4042/s...
# 449  https://www.orthobullets.com/knee-and-sports/3...
# 450  https://www.orthobullets.com/knee-and-sports/1...
# 451  https://www.orthobullets.com/hand/12302/acute-...
#
#                                               Etiology  \
# 0    Pathophysiology\npathoanatomy\ntypically a hig...
# 6    Pathophysiology\nmechanism of injury\nsudden i...
# 8    Pathophysiology\npathoanatomy\ndue to contract...
# 10   Mechanism\ntypically due to underlying anatomi...
# 11   Pathoanatomy\nsynovitis causes the capsuloliga...
# ..                                                 ...
# 443  Pathophysiology\ndue to failure of formation\n...
# 444  Pathophysiology\nneurologic involvement\nmotor...
# 449  Pathophysiology\nvalgus stress\nis the most co...
# 450  Pathophysiology\nmechanism of injury\na valgus...
# 451  Pathophysiology\npathophysiology\nlimb pain oc...
#
#                                               Symptoms  \
# 0    shoulder pain\ninability to move shoulder - ar...
# 6    usually\ndorsal and radial-sided wrist pain\np...
# 8                    may cause problems with shoe wear
# 10   swelling\npatients often report limb swelling ...
# 11                 pain\nwarm joint\nfullness of joint
# ..                                                 ...
# 443              usually painless\nfunctional deficits
# 444  clinical presentation is based on the severity...
# 449  medial joint line pain\ndifficulty ambulating ...
# 450  pain\nmedial knee pain\ninstability\nsubjectiv...
# 451  common symptoms\narm pain\nnausea\nseverity\np...
#
#                                                   Name
# 0    luxatio erecta inferior glenohumeral joint dis...
# 6                scapholunate ligament injury and disi
# 8                                      overlapping toe
# 10                popliteal artery entrapment syndrome
# 11                                synovitis of 2nd mtp
# ..                                                 ...
# 443                             congenital amputations
# 444                                    sacral agenesis
# 449                                  mcl knee injuries
# 450                        posteromedial corner injury
# 451                 acute subclavian artery thrombosis
#
# [180 rows x 4 columns]

# %%
condition_name = df.iloc[0]['Name']
symptoms = df.iloc[0]['Symptoms']
etiology = df.iloc[0]['Etiology']

prompt = f"""
Create a detailed questionnaire for diagnosing {condition_name}. The questionnaire should be in a multiple-choice format and cover the following aspects:

1. **Symptoms**: Based on the symptoms provided, create questions that help identify the presence and severity of each symptom.
   - Symptoms: {symptoms}

2. **Etiology**: Include questions that explore the possible causes and risk factors associated with the condition.
   - Etiology: {etiology}

Each question should have multiple-choice answers with options.

Ensure the questions are clear, concise, and cover all relevant aspects to accurately diagnose {condition_name}.
"""


data = {
    "contents": [
        {
            "parts": [
                {
                    "text": prompt
                }
            ]
        }
    ]
}

# Make the POST request
response = requests.post(url, headers=headers, json=data)

# Print the response
print(response.json())
# Out:
# {'candidates': [{'content': {'parts': [{'text': '## Luxatio Erecta Inferior Glenohumeral Joint Dislocation Questionnaire:\n\n**Please answer the following questions to the best of your ability.**\n\n**1. Symptoms**\n\n**1.1. Shoulder pain:**\n* **a) No pain:** \n* **b) Mild pain, easily managed with over-the-counter medication:**\n* **c) Moderate pain, requiring stronger pain medication:**\n* **d) Severe pain, unable to tolerate any movement:**\n* **e) Intolerable pain, unable to function or manage pain with medication:**\n\n**1.2. Inability to move shoulder:**\n* **a) Full range of motion, no limitations:**\n* **b) Slight limitation in movement, but able to move arm comfortably:**\n* **c) Significant limitation in movement, pain with most movements:**\n* **d) Unable to move shoulder at all, arm stuck in fixed position:**\n* **e) Arm fixed in abducted, overhead position, unable to lower:**\n\n**1.3. Numbness or tingling in the arm or hand:**\n* **a) No numbness or tingling:**\n* **b) Slight numbness or tingling, intermittent and temporary:**\n* **c) Constant numbness or tingling, but not affecting function:**\n* **d) Significant numbness or tingling, affecting function:**\n* **e) Complete loss of sensation in arm or hand:**\n\n**1.4. Weakness or loss of strength in the arm:**\n* **a) No weakness or loss of strength:**\n* **b) Slight weakness, but able to perform daily activities:**\n* **c) Moderate weakness, affecting function in daily activities:**\n* **d) Significant weakness, unable to perform daily activities:**\n* **e) Complete loss of strength in arm:**\n\n**1.5. Visible deformity or swelling around the shoulder:**\n* **a) No visible deformity or swelling:**\n* **b) Slight swelling, but no visible deformity:**\n* **c) Visible deformity, but minimal swelling:**\n* **d) Visible deformity and significant swelling:**\n* **e) Significant swelling, making it difficult to assess deformity:**\n\n**2. Etiology**\n\n**2.1. Mechanism of injury:**\n* **a) No specific injury, gradual onset of symptoms:**\n* **b) Minor injury, like a fall from standing height:**\n* **c) Moderate injury, like a fall from a ladder or a car accident:**\n* **d) High-energy injury, like a car accident or a significant fall:**\n* **e) Unknown mechanism of injury:**\n\n**2.2. Previous shoulder injuries or surgeries:**\n* **a) No prior shoulder injuries or surgeries:**\n* **b) Previous shoulder dislocation, but not in the same position:**\n* **c) Previous shoulder surgery, not related to the current injury:**\n* **d) Previous shoulder dislocation in the same position:**\n* **e) Previous shoulder surgery related to the current injury:**\n\n**2.3. Other associated medical conditions:**\n* **a) No other medical conditions:**\n* **b) Osteoporosis or other bone weakening conditions:**\n* **c) Neurological conditions affecting arm or shoulder function:**\n* **d) Vascular conditions affecting arm or shoulder function:**\n* **e) Other medical conditions, please specify:**\n\n**Please note:** This questionnaire is for informational purposes only and does not constitute a medical diagnosis. It is essential to consult with a qualified healthcare professional for an accurate diagnosis and treatment plan. \n'}], 'role': 'model'}, 'finishReason': 'STOP', 'index': 0, 'safetyRatings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE'}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE'}]}], 'usageMetadata': {'promptTokenCount': 299, 'candidatesTokenCount': 736, 'totalTokenCount': 1035}, 'modelVersion': 'gemini-1.5-flash-001'}

# %%
text = response.json()['candidates'][0]['content']['parts'][0]['text']
# Assuming 'text' is a string variable containing the text with Markdown syntax
text_with_new_lines = text.replace('\\n', '\n')

# Remove common Markdown syntax
cleaned_text = re.sub(r'(\*\*|##|#|_|[*])', '', text_with_new_lines)

print(cleaned_text)
# Out:
#  Luxatio Erecta Inferior Glenohumeral Joint Dislocation Questionnaire:
#
# Please answer the following questions to the best of your ability.
#
# 1. Symptoms
#
# 1.1. Shoulder pain:
#  a) No pain:
#  b) Mild pain, easily managed with over-the-counter medication:
#  c) Moderate pain, requiring stronger pain medication:
#  d) Severe pain, unable to tolerate any movement:
#  e) Intolerable pain, unable to function or manage pain with medication:
#
# 1.2. Inability to move shoulder:
#  a) Full range of motion, no limitations:
#  b) Slight limitation in movement, but able to move arm comfortably:
#  c) Significant limitation in movement, pain with most movements:
#  d) Unable to move shoulder at all, arm stuck in fixed position:
#  e) Arm fixed in abducted, overhead position, unable to lower:
#
# 1.3. Numbness or tingling in the arm or hand:
#  a) No numbness or tingling:
#  b) Slight numbness or tingling, intermittent and temporary:
#  c) Constant numbness or tingling, but not affecting function:
#  d) Significant numbness or tingling, affecting function:
#  e) Complete loss of sensation in arm or hand:
#
# 1.4. Weakness or loss of strength in the arm:
#  a) No weakness or loss of strength:
#  b) Slight weakness, but able to perform daily activities:
#  c) Moderate weakness, affecting function in daily activities:
#  d) Significant weakness, unable to perform daily activities:
#  e) Complete loss of strength in arm:
#
# 1.5. Visible deformity or swelling around the shoulder:
#  a) No visible deformity or swelling:
#  b) Slight swelling, but no visible deformity:
#  c) Visible deformity, but minimal swelling:
#  d) Visible deformity and significant swelling:
#  e) Significant swelling, making it difficult to assess deformity:
#
# 2. Etiology
#
# 2.1. Mechanism of injury:
#  a) No specific injury, gradual onset of symptoms:
#  b) Minor injury, like a fall from standing height:
#  c) Moderate injury, like a fall from a ladder or a car accident:
#  d) High-energy injury, like a car accident or a significant fall:
#  e) Unknown mechanism of injury:
#
# 2.2. Previous shoulder injuries or surgeries:
#  a) No prior shoulder injuries or surgeries:
#  b) Previous shoulder dislocation, but not in the same position:
#  c) Previous shoulder surgery, not related to the current injury:
#  d) Previous shoulder dislocation in the same position:
#  e) Previous shoulder surgery related to the current injury:
#
# 2.3. Other associated medical conditions:
#  a) No other medical conditions:
#  b) Osteoporosis or other bone weakening conditions:
#  c) Neurological conditions affecting arm or shoulder function:
#  d) Vascular conditions affecting arm or shoulder function:
#  e) Other medical conditions, please specify:
#
# Please note: This questionnaire is for informational purposes only and does not constitute a medical diagnosis. It is essential to consult with a qualified healthcare professional for an accurate diagnosis and treatment plan.

# %%
def generate_questionnaire(row):
    condition_name = row['Name']
    symptoms = row['Symptoms']
    etiology = row['Etiology']

    prompt = f"""
    Create a detailed questionnaire for diagnosing {condition_name}. The questionnaire should be in a multiple-choice format and cover the following aspects:

    1. **Symptoms**: Based on the symptoms provided, create questions that help identify the presence and severity of each symptom.
       - Symptoms: {symptoms}

    2. **Etiology**: Include questions that explore the possible causes and risk factors associated with the condition.
       - Etiology: {etiology}

    Each question should have multiple-choice answers with options.

    Ensure the questions are clear, concise, and cover all relevant aspects to accurately diagnose {condition_name}.
    """

    data = {
        "contents": [
            {
                "parts": [
                    {
                        "text": prompt
                    }
                ]
            }
        ]
    }

    # Make the POST request
    response = requests.post(url, headers=headers, json=data)
    # print(response.json())
    try:
        text = response.json()['candidates'][0]['content']['parts'][0]['text']
    except KeyError:
        text = "Error: Missing expected keys in the response."
    # text = response.json()['candidates'][0]['content']['parts'][0]['text']
    # Assuming 'text' is a string variable containing the text with Markdown syntax
    text_with_new_lines = text.replace('\\n', '\n')

    # Remove common Markdown syntax
    cleaned_text = re.sub(r'(\*\*|##|#|_|[*])', '', text_with_new_lines)

    return cleaned_text
    # return response.json()

# %%
df['Questionnaire'] = None

for index, row in df.iterrows():
    if index % 10 == 0:
        print(f"Processing row {index}...")
    if df['Questionnaire'][index] is not None:
        continue
    questionnaire = generate_questionnaire(row)
    df['Questionnaire'][index] = questionnaire
    
df.to_csv('questionnaires2.csv', index=False)
# Out:
# Processing row 0...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# Processing row 10...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# Processing row 20...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# Processing row 30...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# Processing row 40...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# Processing row 70...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# Processing row 130...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# Processing row 410...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# Processing row 450...
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire
# C:\Users\HP\AppData\Local\Temp\ipykernel_7692\330273066.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Questionnaire'][index] = questionnaire

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df['Questionnaire'][0]
# Out:
# " Ossification Posterior Longitudinal Ligament (OPLL) Questionnaire\n\nThis questionnaire is intended for informational purposes only and does not constitute medical advice. Please consult with a qualified healthcare professional for diagnosis and treatment.\n\n1. Symptoms:\n\n1.1 Do you experience any of the following symptoms?\n\n    a) Numbness or tingling in your hands or feet\n    b) Weakness in your arms or legs\n    c) Difficulty walking or balance issues\n    d) Pain in your neck or back\n    e) Bowel or bladder dysfunction\n    f) Difficulty with fine motor skills\n    g) None of the above\n\n1.2 If you experience any of the symptoms above, how often do you experience them?\n\n    a) Occasionally\n    b) Frequently\n    c) Constantly\n\n1.3 How would you rate the severity of your symptoms?\n\n    a) Mild\n    b) Moderate\n    c) Severe\n\n2. Etiology:\n\n2.1 Do you have a history of any of the following conditions?\n\n    a) Diabetes\n    b) Obesity\n    c) High blood pressure\n    d) High cholesterol\n    e) Thyroid disorders\n    f) None of the above\n\n2.2 Do you follow a specific diet?\n\n    a) High salt, low meat diet\n    b) Low salt, high meat diet\n    c) Vegetarian diet\n    d) Other (please specify)\n    e) No specific diet\n\n2.3 Do you have any factors that may contribute to poor calcium absorption?\n\n    a) Vitamin D deficiency\n    b) Celiac disease\n    c) Crohn's disease\n    d) Other (please specify)\n    e) None of the above\n\n2.4 Do you engage in activities that put significant mechanical stress on your spine?\n\n    a) Heavy lifting\n    b) Repetitive motions\n    c) Contact sports\n    d) Other (please specify)\n    e) None of the above\n\n3. Additional Information:\n\n3.1 Have you ever had any spinal surgeries?\n\n    a) Yes\n    b) No\n\n3.2 Have you had any previous imaging studies of your spine (e.g., X-ray, MRI)?\n\n    a) Yes\n    b) No\n\n3.3 Please provide any relevant information about your family history of spinal conditions.\n\nPlease note: This questionnaire is not a substitute for a medical evaluation. It is important to consult with a qualified healthcare professional for a proper diagnosis and treatment plan.  \n"

# %%
text = df['Questionnaire'][0]

# %%
text
# Out:
# " Ossification Posterior Longitudinal Ligament (OPLL) Questionnaire\n\nThis questionnaire is intended for informational purposes only and does not constitute medical advice. Please consult with a qualified healthcare professional for diagnosis and treatment.\n\n1. Symptoms:\n\n1.1 Do you experience any of the following symptoms?\n\n    a) Numbness or tingling in your hands or feet\n    b) Weakness in your arms or legs\n    c) Difficulty walking or balance issues\n    d) Pain in your neck or back\n    e) Bowel or bladder dysfunction\n    f) Difficulty with fine motor skills\n    g) None of the above\n\n1.2 If you experience any of the symptoms above, how often do you experience them?\n\n    a) Occasionally\n    b) Frequently\n    c) Constantly\n\n1.3 How would you rate the severity of your symptoms?\n\n    a) Mild\n    b) Moderate\n    c) Severe\n\n2. Etiology:\n\n2.1 Do you have a history of any of the following conditions?\n\n    a) Diabetes\n    b) Obesity\n    c) High blood pressure\n    d) High cholesterol\n    e) Thyroid disorders\n    f) None of the above\n\n2.2 Do you follow a specific diet?\n\n    a) High salt, low meat diet\n    b) Low salt, high meat diet\n    c) Vegetarian diet\n    d) Other (please specify)\n    e) No specific diet\n\n2.3 Do you have any factors that may contribute to poor calcium absorption?\n\n    a) Vitamin D deficiency\n    b) Celiac disease\n    c) Crohn's disease\n    d) Other (please specify)\n    e) None of the above\n\n2.4 Do you engage in activities that put significant mechanical stress on your spine?\n\n    a) Heavy lifting\n    b) Repetitive motions\n    c) Contact sports\n    d) Other (please specify)\n    e) None of the above\n\n3. Additional Information:\n\n3.1 Have you ever had any spinal surgeries?\n\n    a) Yes\n    b) No\n\n3.2 Have you had any previous imaging studies of your spine (e.g., X-ray, MRI)?\n\n    a) Yes\n    b) No\n\n3.3 Please provide any relevant information about your family history of spinal conditions.\n\nPlease note: This questionnaire is not a substitute for a medical evaluation. It is important to consult with a qualified healthcare professional for a proper diagnosis and treatment plan.  \n"

# %%
import re
combined_prompt = """
Create a combined diagnostic questionnaire in a multiple-choice format that can differentiate between multiple medical conditions. The following conditions and their associated symptoms and etiologies should be included:

"""

# Adding each condition and its details to the prompt
for index, row in df.iterrows():
    condition_name = row['Name']
    symptoms = row['Symptoms']
    etiology = row['Etiology']

    prompt = f"""
    Condition: {condition_name}
    Symptoms: {symptoms}
    Etiology: {etiology}
    """
    combined_prompt += prompt + "\n"

combined_prompt += """
Instructions for the questionnaire:
- For **each question**, ensure it can help in identifying one or more of the above conditions.
- The questionnaire should ask about **symptoms**, **possible causes**, and **risk factors** common across the conditions.
- Each question should be in multiple-choice format and designed in such a way that it can help distinguish between these conditions based on the selected answers.
- Ensure that each question addresses the presence, frequency, severity, or nature of symptoms and possible causes in a way that would help in differentiating the conditions.
- Provide clear and concise multiple-choice options for each question.

The goal of the questionnaire is to accurately identify which of these conditions a person might be suffering from based on their responses.
also, give the possible combinations of answers which can lead to a particular diagnosis.
"""

# Define the request data
data = {
    "contents": [
        {
            "parts": [
                {
                    "text": combined_prompt
                }
            ]
        }
    ]
}

# Make the POST request
response = requests.post(url, headers=headers, json=data)
# print(response.json())
try:
     text = response.json()['candidates'][0]['content']['parts'][0]['text']
except KeyError:
     text = "Error: Missing expected keys in the response."
# text = response.json()['candidates'][0]['content']['parts'][0]['text']
# Assuming 'text' is a string variable containing the text with Markdown syntax
text_with_new_lines = text.replace('\\n', '\n')

# Remove common Markdown syntax
cleaned_text = re.sub(r'(\*\*|##|#|_|[*])', '', text_with_new_lines)

print(cleaned_text)
# Out:
#  Combined Diagnostic Questionnaire for Spine Conditions:
#
# Instructions: Please answer each question honestly and to the best of your ability. Choose the most appropriate response from the provided options.
#
# 1. What is your primary symptom?
#
# a) Neck pain
# b) Back pain
# c) Buttock pain
# d) Leg pain
# e) Neck stiffness
# f) Headache
#
# 2.  When is your pain worse?
#
# a) In the morning
# b) After activity
# c) When standing for prolonged periods
# d) When sitting for prolonged periods
# e) When walking
# f) When bending forward
# g) When extending your back
# h) At night
# i) With neck movement
#
# 3. Where is your pain located?
#
# a) Upper back
# b) Lower back
# c) Neck
# d) Buttocks
# e) Legs (specify location: unilateral or bilateral, which leg(s))
# f)  Occipital region
#
# 4. Do you experience any of the following neurological symptoms?
#
# a) Numbness or tingling in your arms or legs
# b) Weakness in your arms or legs
# c) Difficulty with hand dexterity (dropping objects, difficulty manipulating fine objects)
# d) Difficulty with grip strength
# e) Difficulty with overhead activities
# f) Gait instability
# g) Bowel or bladder dysfunction
# h) Difficulty with horizontal gaze
#
# 5.  Do you experience any of the following systemic symptoms?
#
# a) Fever
# b) Weight loss
# c) Fatigue
# d) Malaise
# e) Shortness of breath
#
# 6.  Do you have a history of any of the following?
#
# a) Trauma (e.g., car accident, fall, sports injury)
# b) Surgery to the spine
# c) Prior infection
# d) Cancer
# e) Diabetes
# f) Rheumatoid arthritis
# g)  Osteoporosis
#
# 7.  Do you have any of the following risk factors?
#
# a) Obesity
# b) Smoking
# c)  High salt-low meat diet
# d) Poor calcium absorption
# e)  Prolonged sitting
# f)  Repetitive heavy lifting
#
# 8.  Is your pain relieved by any of the following?
#
# a) Rest
# b) Sitting
# c) Leaning forward
# d) Tight fitting belt
# e)  Anti-inflammatory medications
#
# Possible Diagnosis Combinations:
#
# Cervical Radiculopathy:  1a, 1e, 4a, 4b, 4d, 4e, 6a, 8a
#
# Cervical Myelopathy:  1a, 1e, 4c, 4f, 4g, 8a
#
# Ossification of the Posterior Longitudinal Ligament (OPLL): 1a, 1e, 4c, 4f, 4g, 6g
#
# Odontoid Fracture: 1a, 1i, 2i, 6a
#
# Cervical Facet Dislocations and Fractures: 1a, 1i, 4a, 4b, 6a
#
# Adult Spinal Deformity:  1b, 1c, 1d, 2c, 2g, 4a, 4b, 6a, 6g, 8a, 8b
#
# Ankylosing Spondylitis: 1a, 1b, 1e, 2a, 4h, 5e, 6f
#
# Pathologic Scoliosis: 1b, 2h, 6d, 8e
#
# Osteoporotic Vertebral Compression Fracture: 1b, 2h, 6g, 8a, 8e
#
# Pediatric Spondylolysis and Spondylolisthesis:  1b, 2b, 2g, 4a, 4b, 4f, 4g
#
# Lumbar Spinal Stenosis:  1b, 1c, 1d, 2c, 2e, 2g, 4a, 4b, 4f, 4g, 6g, 8a, 8b, 8c
#
# Sacroiliac Joint Dysfunction: 1b, 1c, 1d, 2b, 2g, 8d
#
# Spinal Epidural Abscess: 1b, 2h, 4a, 4b, 5a, 6c
#
# Adult Pyogenic Vertebral Osteomyelitis: 1b, 2h, 4a, 4b, 5a, 6c
#
# Atlantoaxial Rotatory Displacement (AARD): 1a, 1i, 6f, 6c
#
# Adult Isthmic Spondylolisthesis: 1b, 2b, 2g, 4a, 4b, 8a
#
# Discogenic Back Pain: 1b, 2f, 8a
#
# Diabetic Charcot Neuropathy: 1b, 1c, 1d, 2b, 4a, 5b, 6e
#
# Degenerative Spondylolisthesis: 1b, 1c, 1d, 2c, 2g, 4a, 4b, 4f, 4g, 8a, 8b
#
# Low Back Pain: 1b, 2b, 2f, 2g, 4a, 4b, 4f, 4g, 6a, 6b, 6d, 6e, 6g, 8a, 8b
#
# Scheuermanns Kyphosis: 1b, 2a, 4a, 4b, 6a, 6b, 6g
#
# Metastatic Disease of Spine: 1b, 2h, 4a, 4b, 5a, 5b, 5c, 5d, 6d
#
# Neck Injuries in Athletes: 1a, 1i, 4a, 4b, 6a, 6b
#
# Congenital Muscular Torticollis: 1a, 1e, 6a, 6b
#
# Lumbar Disc Herniation: 1b, 1c, 1d, 2d, 2f, 4a, 4b, 4f, 4g, 6g, 8a
#
# Please note: This questionnaire is for educational purposes only and is not a substitute for professional medical advice. If you are experiencing any of these symptoms, it is crucial to consult with a healthcare professional for an accurate diagnosis and appropriate treatment plan.
